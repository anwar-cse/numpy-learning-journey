# %% [markdown]
# NaN

# %%
import numpy as np
arr=np.array([1,2,3,np.nan,3,4])
print(arr)
print(np.isnan(arr))
print(np.mean(arr))
print(np.nanmean(arr))
clean=arr[~np.isnan(arr)]
print(clean)

arr=np.array([1,2,3,np.nan,3,4])
mean=np.nanmean(arr)
# Out:
# [ 1.  2.  3. nan  3.  4.]
# [False False False  True False False]
# nan
# 2.6
# [1. 2. 3. 3. 4.]
